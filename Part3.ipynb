# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka-code/Coding-Blocks-ML-DL-/blob/main/Part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Pandas**

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
user_data = {
    "MarksA" : np.random.randint(1,100,5),
    "MarksB" : np.random.randint(50,100,5),
    "MarksC" : np.random.randint(1,100,5),
}

# %%
df = pd.DataFrame(user_data)

# %%
df
# Out:
#    MarksA  MarksB  MarksC
# 0       9      88      17
# 1      37      62      96
# 2      14      68      65
# 3      33      67      34
# 4      85      64      73

# %%
df.head(n=3) # first 3
# Out:
#    MarksA  MarksB  MarksC
# 0       9      88      17
# 1      37      62      96
# 2      14      68      65

# %%
df.tail(n=3) # last 3
# Out:
#    MarksA  MarksB  MarksC
# 2      14      68      65
# 3      33      67      34
# 4      85      64      73

# %%
df.describe()
# Out:
#           MarksA    MarksB     MarksC
# count   5.000000   5.00000   5.000000
# mean   35.600000  69.80000  57.000000
# std    30.096511  10.44988  31.503968
# min     9.000000  62.00000  17.000000
# 25%    14.000000  64.00000  34.000000
# 50%    33.000000  67.00000  65.000000
# 75%    37.000000  68.00000  73.000000
# max    85.000000  88.00000  96.000000

# %% [markdown]
# Playing with Rows & Columns

# %%
df
# Out:
#    MarksA  MarksB  MarksC
# 0       9      88      17
# 1      37      62      96
# 2      14      68      65
# 3      33      67      34
# 4      85      64      73

# %%
df.iloc[3] #prints details of the third row
# Out:
# MarksA    33
# MarksB    67
# MarksC    34
# Name: 3, dtype: int64

# %%
df.iloc[3,1] #3rd row and 1st column
# Out:
# 67

# %%
df.iloc[:3, [1,2]] #before 3rd row and columns 1 and 2
# Out:
#    MarksB  MarksC
# 0      88      17
# 1      62      96
# 2      68      65
